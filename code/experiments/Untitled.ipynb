# %% [markdown]
# # Setup

# %% [markdown]
# ## Jupyter extensions

# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
# %pwd
# Out:
# /home/oli/Research/interpreting-rewards/code
# '/home/oli/Research/interpreting-rewards/code'

# %%
#start by adding parent directory...
import os
import sys
import inspect

from matplotlib import pyplot as plt

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(-1, parentdir) 
# Now build environment
# import numpy as np
import torch
import numpy
import primitives as prim
from environs import GridWorld
from utils import broadcompress

GW = GridWorld.make(11,8, noise=0.1)


# R0pt.require_grad()

# %%
pi = GW.random_policy(det=True)

# %%
R = np.zeros(GW.SAshape)
R[:,0] = 1
GW.draw(tris=R, policy=pi)
# Out:
# 352 triangles, and 	 Mshape: (352,) totaling  352
# (196,)
